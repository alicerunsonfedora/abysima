# %% [markdown]
# # Project Abysima: Generating a Language with Machine Learning
#
# The following notebook will experiment with generating a language using neural networks and generative deep learning.
# This is, by no means, a production-ready system, nor is it a complete network; rather, the purpose of this experiment
# is to see what is possible with creating a language.
#
# For more information on the process and supporting research, please refer to the Linguistics Paper document found in the
# `01 - Areas of Responsibility` directory.
#
# The following source code and datasets are licensed under the Mozilla Public License v2.0. Please refer to the LICENSE
# file that came with this repository for more information on what your rights are with usage and modification of this
# software. If a LICENSE file is not provided, you can obtain a copy at https://www.mozilla.org/en-US/MPL/2.0/.

# %% [markdown]
# ## Part 1: Initial Setup
#
# We'll need to write some utilities and codes that will allow us to generate, predict, and validate words. This
# section will allow us to do just that.

# %%
# Unix-based and Unix-like systems have a file on the computer that contains a list of words used for spell-checking.
# This file is located in /usr/share/dict/words and contains various parts of speech, including proper nouns. For the
# purposes of this experiment, a copy provided from an installation of Pop!_OS 20.04 LTS (based on Ubuntu) will be used.
# If that file cannot be located, the file located on the system will be used instead.
import os


def is_admissible(word: str) -> bool:
    """Returns whether a word is considered admissible for the dataset.
    
    For the purposes of the dataset, a word is admissible if it conforms to the following:
    - The word must be at least three characters long.
    - The word only contains ASCII characters; i.e., the word does not have any accents.
    - The word only contains letters in the alphabet
    - The word is not a proper noun or acronym (i.e., the word doesn't have uppercase letters)
    - The word is not a contraction.
    """
    real_word = word.strip()
    return len(real_word) >= 3 and real_word.isascii() and real_word.isalpha() and real_word.islower(
    ) and not real_word.endswith("'s")


# Open the words file and grab all of the admissible words.
WORDS_FILE = "outside_sources/words" if os.path.isfile(
    "outside_sources/words") else "/usr/share/dict/words"
with open(WORDS_FILE, 'r') as words:
    valid_words = [
        w.strip().lower() for w in words.readlines() if is_admissible(w)
    ]
print(f"Number of admissible words from {WORDS_FILE}: {len(valid_words)}")

# Open the converted dataset from the Wiktionary page and import that into the list of valid words.
with open("outside_sources/jp-romaji.txt") as jp_data:
    valid_words += [w.strip().lower() for w in jp_data.readlines()]

original_valid = valid_words.copy()

print(f"Number of total words including Japanese words: {len(valid_words)}")
# Out:
# Number of admissible words from outside_sources/words: 63160
# Number of total words including Japanese words: 63775

# %%
# Create a bunch of nonsencial words that are not valid.
from random import randrange
from string import ascii_lowercase


def random_string(max_size: int) -> str:
    """Returns a string of a random length between 3 and 12 characters, with no syllabic structure in mind."""
    length = randrange(3, max_size) if max_size > 3 else 3
    string = ""
    for _ in range(length):
        next_index = randrange(0, len(ascii_lowercase) - 1)
        string += ascii_lowercase[next_index]
    return string

# Assemble the dataset with the valid and invalid words. Words that are valid will be marked as 1 for its output,
# and words that are not valid are marked as 0 for its output.
from string import ascii_lowercase
import numpy as np


def map_word(word: str) -> list:
    """Returns a list of numbers from 1 to 26 that represent the various letters in the alphabet."""
    get_idx = lambda i: ascii_lowercase.index(i) + 1
    return [get_idx(c) for c in word]

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Get the average length of words in the dataset, and filter out any words larger than the average length.
avg_length = sum([len(str(w)) for w in valid_words]) // len(valid_words)
print(f"Average word length: {avg_length}")
valid_words = [w for w in valid_words if len(w) <= avg_length]
print(f"Filtered dataset size based on average length: {len(valid_words)}")

# Create nonsensical words that match the average length.
invalid = [random_string(avg_length) for _ in range(len(valid_words))]
print(invalid[:10])

# Encode the data set into a format that the neural network will be able to understand.
encoded_correct = [map_word(str(word)) for word in valid_words]
encoded_invalid = [map_word(str(word)) for word in invalid]

Y_correct   = [[1] for _ in range(len(encoded_correct))]
Y_incorrect = [[0] for _ in range(len(encoded_invalid))]

# Use padding to make all the words the same length, adding zeroes at the end.
pre_padded_X = np.array(encoded_correct + encoded_invalid, dtype=object)
X = pad_sequences(pre_padded_X, padding="post", maxlen=avg_length)

# Divide the dataset's elements by the number of letters in the alphabet to normalize the data.
X = X / 26
Y = np.array(Y_correct + Y_incorrect)

# print(X.shape)
print(X[:5])
# Out:
# Average word length: 8
# Filtered dataset size based on average length: 35691
# ['bmled', 'tacr', 'jmldsd', 'hfb', 'hnv', 'cduqi', 'grlcpu', 'fwv', 'ivxv', 'pmllp']
# [[0.03846154 0.03846154 0.69230769 0.15384615 0.84615385 0.03846154
#   0.69230769 0.42307692]
#  [0.03846154 0.07692308 0.03846154 0.11538462 0.34615385 0.
#   0.         0.        ]
#  [0.03846154 0.07692308 0.03846154 0.11538462 0.42307692 0.
#   0.         0.        ]
#  [0.03846154 0.07692308 0.03846154 0.11538462 0.80769231 0.73076923
#   0.         0.        ]
#  [0.03846154 0.07692308 0.03846154 0.11538462 0.80769231 0.73076923
#   0.19230769 0.73076923]]

# %% [markdown]
# ## Part 2: Splitting Models for Validation and Testing
#
# In order to prevent the neural network we will generate from overcorrecting itself or memorizing the data we give
# it, we will create three different sets of the dataset: a training set, a validation set, and a testing set. The
# training set will be used to train the model, and the model will use the validation set occasionally to validate
# that it isn't overfitting. We will then use the testing set to test out the model and see what comes out of it.
#
# To accomplish this, we will use a 60% training/20% validation/20% testing split for the datasets.

# %%
# Split the data in training and testing data. When we fit the model, we can specify a validation set.
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=1498)

# %% [markdown]
# ## Part 3: Creating The Predictive Model
#
# Now that we have a dataset, we will create the neural network model with Keras and fit it using the training data.
# This will also use a small portion of that data for validation purposes.

# %%
NUM_EPOCHS = 200
SM_BATCH_SIZE = 16
VR_BATCH_SIZE = 64

# %%
# Start by creating the model.
from tensorflow import keras
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping

print(keras.__version__)

init_model = keras.Sequential(name="Abysima_2")
init_model.add(Dense(avg_length, input_dim=avg_length, activation='relu'))
init_model.add(Dense(avg_length * 4, activation='relu'))
# model.add(Dense(max_len/4, activation='relu'))
init_model.add(Dense(1, activation='sigmoid'))

# Create an early stopping mechanism to stop early if accuracy isn't improving after a certain point. This prevents
# unnecessary computations.
stop_early = EarlyStopping(monitor='accuracy', patience=7)

# Compile the model.
init_model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
init_model.summary()
# Out:
# 2.6.0
# Model: "Abysima_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_16 (Dense)             (None, 8)                 72
# _________________________________________________________________
# dense_17 (Dense)             (None, 32)                288
# _________________________________________________________________
# dense_18 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 393
# Trainable params: 393
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fit the model to our dataset. In this instance, the model will run a batch gradient descent learning algorithm
# for 100 epochs with a determined batch size. Additionally, it will set aside 20% of the data for validation.
training_results = init_model.fit(X_train,
                                  y_train,
                                  epochs=NUM_EPOCHS,
                                  batch_size=VR_BATCH_SIZE,
                                  verbose=1,
                                  validation_split=0.2,
                                  callbacks=[])
# Out:
# Epoch 1/200
#  11/714 [..............................] - ETA: 3s - loss: 0.7001 - accuracy: 0.5043
# 2021-11-05 17:01:04.733034: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
#
200
# 714/714 [==============================] - 4s 5ms/step - loss: 0.4448 - accuracy: 0.7781 - val_loss: 0.4493 - val_accuracy: 0.7781
# Epoch 182/200
# 714/714 [==============================] - 4s 5ms/step - loss: 0.4446 - accuracy: 0.7792 - val_loss: 0.4471 - val_accuracy: 0.7831
# Epoch 183/200
# 714/714 [==============================] - 4s 5ms/step - loss: 0.4446 - accuracy: 0.7789 - val_loss: 0.4457 - val_accuracy: 0.7819
# Epoch 184/200
# 714/714 [==============================] - 4s 5ms/step - loss: 0.4443 - accuracy: 0.7806 - val_loss: 0.4471 - val_accuracy: 0.7745
# Epoch 185/200
# 714/714 [==============================] - 4s 5ms/step - loss: 0.4441 - accuracy: 0.7788 - val_loss: 0.4472 - val_accuracy: 0.7787
# Epoch 186/200
# 714/714 [==============================] - 4s 5ms/step - loss: 0.4441 - accuracy: 0.7784 - val_loss: 0.4474 - val_accuracy: 0.7811
# Epoch 187/200
# 714/714 [==============================] - 4s 5ms/step - loss: 0.4438 - accuracy: 0.7803 - val_loss: 0.4440 - val_accuracy: 0.7799
# Epoch 188/200
# 714/714 [==============================] - 4s 5ms/step - loss: 0.4435 - accuracy: 0.7798 - val_loss: 0.4456 - val_accuracy: 0.7803
# Epoch 189/200
# 714/714 [==============================] - 4s 5ms/step - loss: 0.4431 - accuracy: 0.7806 - val_loss: 0.4451 - val_accuracy: 0.7808
# Epoch 190/200
# 714/714 [==============================] - 4s 5ms/step - loss: 0.4431 - accuracy: 0.7806 - val_loss: 0.4466 - val_accuracy: 0.7804
# Epoch 191/200
# 714/714 [==============================] - 4s 5ms/step - loss: 0.4431 - accuracy: 0.7812 - val_loss: 0.4443 - val_accuracy: 0.7841
# Epoch 192/200
# 714/714 [==============================] - 4s 5ms/step - loss: 0.4427 - accuracy: 0.7798 - val_loss: 0.4425 - val_accuracy: 0.7801
# Epoch 193/200
# 714/714 [==============================] - 4s 5ms/step - loss: 0.4430 - accuracy: 0.7811 - val_loss: 0.4445 - val_accuracy: 0.7789
# Epoch 194/200
# 714/714 [==============================] - 4s 5ms/step - loss: 0.4431 - accuracy: 0.7796 - val_loss: 0.4453 - val_accuracy: 0.7825
# Epoch 195/200
# 714/714 [==============================] - 4s 5ms/step - loss: 0.4424 - accuracy: 0.7806 - val_loss: 0.4454 - val_accuracy: 0.7762
# Epoch 196/200
# 714/714 [==============================] - 4s 5ms/step - loss: 0.4418 - accuracy: 0.7816 - val_loss: 0.4419 - val_accuracy: 0.7838
# Epoch 197/200
# 714/714 [==============================] - 4s 5ms/step - loss: 0.4422 - accuracy: 0.7809 - val_loss: 0.4453 - val_accuracy: 0.7808
# Epoch 198/200
# 714/714 [==============================] - 4s 5ms/step - loss: 0.4425 - accuracy: 0.7816 - val_loss: 0.4450 - val_accuracy: 0.7840
# Epoch 199/200
# 714/714 [==============================] - 4s 5ms/step - loss: 0.4420 - accuracy: 0.7812 - val_loss: 0.4427 - val_accuracy: 0.7842
# Epoch 200/200
# 714/714 [==============================] - 4s 5ms/step - loss: 0.4414 - accuracy: 0.7815 - val_loss: 0.4434 - val_accuracy: 0.7811

# %%
# Plot the accuracy and loss changes for comparison. If we see an overlap, there may be overfitting involved.
from matplotlib import pyplot as plt

plt.plot(training_results.history['accuracy'],
         label='Accuracy over iterations')
plt.plot(training_results.history['loss'], label='Loss over iterations')
plt.legend()

# %%
plt.plot(training_results.history['val_accuracy'],
         label='Validation accuracy over iterations')
plt.plot(training_results.history['val_loss'],
         label='Validation loss over iterations')
plt.legend()

# %% [markdown]
# ## Part 4: Testing with the Testing Set
#
# Now that the model is trained, we will use the testing set to test the results of the model's fitting process.

# %%
# Predict the testing data.
test_predictions = init_model.predict(X_test)


def unmap_word(word: list) -> str:
    """Returns a string from a list of numbers from 0 to 1 that represent the different letters of the alphabet.
    
    For numbers less than or equal to zero, they are skipped since they are not valid entries.
    """
    result = ""
    for num in word:
        if num < 1:
            continue
        result = result + ascii_lowercase[int(num) - 1]
    return result


# Go through each of the predictions and store the number of predictions it got correct, and capture any failed
# predictions for inspection.
number_correct = 0
errors = []
for idx, prediction in enumerate(test_predictions):
    actual = y_test[idx]
    if prediction == actual:
        number_correct += 1
    else:
        errors.append((idx, prediction, actual))

# Calculate the accuracy percentage.
accuracy_percentage = (number_correct / len(y_test)) * 100
print(f"Percent correct: {accuracy_percentage:02f}%")
print(f"Number of incorrect predictions: {len(y_test) - number_correct}")

# Print the first five of the incorrect predictions.
print("===Incorrect Predictions===")
for idx, pred, act in errors[:5]:
    word = unmap_word(X_test[idx] * 26)
    pred_str = "valid" if pred else "invalid"
    act_str = "valid" if act else "invalid"
    print(
        f"Prediction was {pred_str},\t where actual was {act_str}\t\tWord: {word}"
    )
# Out:
# 2021-11-05 17:13:00.738707: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# Percent correct: 14.729985%
# Number of incorrect predictions: 12174
# ===Incorrect Predictions===
# Prediction was valid,	 where actual was invalid		Word: mebxkfg
# Prediction was valid,	 where actual was valid		Word: filets
# Prediction was valid,	 where actual was invalid		Word: wph
# Prediction was valid,	 where actual was invalid		Word: itnrgn
# Prediction was valid,	 where actual was valid		Word: cnaches

# %% [markdown]
# ## Part 5: Filtering Out "Invalid" Words in the Test Dictionary
#
# Now that we have model that seems to be reasonably accurate, we can use our test dictionary to filter out words
# that the network considers invalid.

# %%
# Grab the contents of the test dictionary, which contains completely randomly-generated words from the random word
# generator defined in random_strings. These words follow common syllabic structures and will be filtered according to
# what the network defines as a valid word later.

with open("test_dict.txt", "r") as dict_file:
    test_dict = [word.strip() for word in dict_file.readlines()]

print(test_dict[:10])
# Out:
# ['xewetov', 'rskyesphbdj', 'wudnanvo', 'does', 'doowkguy', 'qtasvymmeq', 'hihebuxa', 'kftealnlhnp', 'gevhenly', 'deacgiecj']

# %%
# Encode the test_dict the same way we encoded the dataset.
encoded_test = np.array([map_word(w) for w in test_dict if len(w) <= avg_length], dtype=object)
encoded_test = pad_sequences(encoded_test, padding="post", maxlen=avg_length)

# Make predictions of the test_dict and collect all of the words it considered valid.
dict_predictions = init_model.predict(encoded_test)
valid_dictionary = []
for idx, prediction in enumerate(dict_predictions):
    if prediction == 0:
        continue
    valid_dictionary.append(test_dict[idx])

# Print some of the valid words, as well as how big the list actually is.
trim_count = len([w for w in test_dict if len(w) <= avg_length]) - len(valid_dictionary)
print(
    f"Trimmed {trim_count} invalid words from the test dictionary (now size {len(test_dict)})."
)
print(valid_dictionary[:10])
# Out:
# Trimmed 168 invalid words from the test dictionary (now size 500).
# ['rskyesphbdj', 'does', 'doowkguy', 'qtasvymmeq', 'kftealnlhnp', 'deacgiecj', 'gxquivrbvb', 'biuczjyukkc', 'juimki', 'wuacv']
# 2021-11-05 17:13:01.167709: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.

# %% [markdown]
# ## Part 7: Scaling Down the Network
#
# The same steps for creating the network apply here; however, the dataset has now changed to words consisting of only three letters.

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

small_valid_words = [w for w in original_valid if len(w) <= 3]
small_invalid = [random_string(3) for _ in range(len(small_valid_words))]

small_encoded_correct = [map_word(str(word)) for word in small_valid_words]
small_encoded_invalid = [map_word(str(word)) for word in small_invalid]

Y_small_correct   = [[1] for _ in range(len(small_encoded_correct))]
Y_small_incorrect = [[0] for _ in range(len(small_encoded_invalid))]

# Use padding to make all the words the same length, adding zeroes at the end.
pre_padded_X_small = np.array(small_encoded_correct + small_encoded_invalid, dtype=object)
small_X = pad_sequences(pre_padded_X_small, padding="post", maxlen=3)

# Divide the dataset's elements by the number of letters in the alphabet to normalize the data.
small_X = small_X / 26
small_Y = np.array(Y_small_correct + Y_small_incorrect)

# print(X.shape)
print(small_X[:5])
# Out:
# [[0.03846154 0.11538462 0.19230769]
#  [0.03846154 0.11538462 0.76923077]
#  [0.03846154 0.15384615 0.15384615]
#  [0.03846154 0.15384615 0.57692308]
#  [0.03846154 0.15384615 0.73076923]]

# %%
# Start by creating the model.
from tensorflow import keras
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping

small_model = keras.Sequential(name="AbysimaSmall_2")
small_model.add(Dense(3, input_dim=3, activation='relu'))
small_model.add(Dense(12, activation='relu'))
small_model.add(Dense(1, activation='sigmoid'))

# Compile the model.
small_model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
small_model.summary()
# Out:
# Model: "AbysimaSmall_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_19 (Dense)             (None, 3)                 12
# _________________________________________________________________
# dense_20 (Dense)             (None, 12)                48
# _________________________________________________________________
# dense_21 (Dense)             (None, 1)                 13
# =================================================================
# Total params: 73
# Trainable params: 73
# Non-trainable params: 0
# _________________________________________________________________

# %%
from sklearn.model_selection import train_test_split

small_X_train, small_X_test, small_y_train, small_y_test = train_test_split(small_X, small_Y, test_size=0.2, random_state=1498)
small_training_results = small_model.fit(small_X_train,
                                         small_y_train,
                                         epochs=NUM_EPOCHS,
                                         batch_size=SM_BATCH_SIZE,
                                         verbose=1,
                                         validation_split=0.2,
                                         callbacks=[])
# Out:
# Epoch 1/200
#  7/57 [==>...........................] - ETA: 0s - loss: 0.6936 - accuracy: 0.4018
# 2021-11-05 17:13:01.377610: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 57/57 [==============================] - 1s 8ms/step - loss: 0.6932 - accuracy: 0.4755 - val_loss: 0.6928 - val_accuracy: 0.5156
# Epoch 2/200
# 14/57 [======>.......................] - ETA: 0s - loss: 0.6922 - accuracy: 0.5268
# 2021-11-05 17:13:01.810731: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 57/57 [==============================] - 0s 5ms/step - loss: 0.6926 - accuracy: 0.5312 - val_loss: 0.6925 - val_accuracy: 0.5333
# Epoch 3/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.6918 - accuracy: 0.5612 - val_loss: 0.6920 - val_accuracy: 0.5156
# Epoch 4/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.6912 - accuracy: 0.5390 - val_loss: 0.6916 - val_accuracy: 0.5111
# Epoch 5/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.6905 - accuracy: 0.5579 - val_loss: 0.6912 - val_accuracy: 0.5156
# Epoch 6/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.6897 - accuracy: 0.5501 - val_loss: 0.6911 - val_accuracy: 0.5022
# Epoch 7/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.6892 - accuracy: 0.5523 - val_loss: 0.6911 - val_accuracy: 0.5067
# Epoch 8/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.6886 - accuracy: 0.5501 - val_loss: 0.6907 - val_accuracy: 0.4933
# Epoch 9/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.6878 - accuracy: 0.5523 - val_loss: 0.6896 - val_accuracy: 0.4889
# Epoch 10/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.6872 - accuracy: 0.5523 - val_loss: 0.6892 - val_accuracy: 0.4844
# Epoch 11/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.6864 - accuracy: 0.5501 - val_loss: 0.6888 - val_accuracy: 0.4889
# Epoch 12/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.6859 - accuracy: 0.5612 - val_loss: 0.6884 - val_accuracy: 0.4889
# Epoch 13/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.6854 - accuracy: 0.5379 - val_loss: 0.6881 - val_accuracy: 0.4889
# Epoch 14/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.6858 - accuracy: 0.5523 - val_loss: 0.6882 - val_accuracy: 0.4978
# Epoch 15/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.6848 - accuracy: 0.5412 - val_loss: 0.6877 - val_accuracy: 0.5022
# Epoch 16/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.6842 - accuracy: 0.5546 - val_loss: 0.6877 - val_accuracy: 0.5022
# Epoch 17/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.
200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.6696 - accuracy: 0.5657 - val_loss: 0.6767 - val_accuracy: 0.5156
# Epoch 185/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.6699 - accuracy: 0.5612 - val_loss: 0.6785 - val_accuracy: 0.5333
# Epoch 186/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.6695 - accuracy: 0.5612 - val_loss: 0.6767 - val_accuracy: 0.5244
# Epoch 187/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.6692 - accuracy: 0.5646 - val_loss: 0.6767 - val_accuracy: 0.5156
# Epoch 188/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.6698 - accuracy: 0.5601 - val_loss: 0.6768 - val_accuracy: 0.5244
# Epoch 189/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.6699 - accuracy: 0.5746 - val_loss: 0.6759 - val_accuracy: 0.5244
# Epoch 190/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.6694 - accuracy: 0.5657 - val_loss: 0.6765 - val_accuracy: 0.5289
# Epoch 191/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.6691 - accuracy: 0.5735 - val_loss: 0.6765 - val_accuracy: 0.5200
# Epoch 192/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.6701 - accuracy: 0.5624 - val_loss: 0.6761 - val_accuracy: 0.5244
# Epoch 193/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.6693 - accuracy: 0.5668 - val_loss: 0.6765 - val_accuracy: 0.5200
# Epoch 194/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.6694 - accuracy: 0.5579 - val_loss: 0.6759 - val_accuracy: 0.5244
# Epoch 195/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.6692 - accuracy: 0.5713 - val_loss: 0.6765 - val_accuracy: 0.5200
# Epoch 196/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.6700 - accuracy: 0.5601 - val_loss: 0.6764 - val_accuracy: 0.5200
# Epoch 197/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.6686 - accuracy: 0.5679 - val_loss: 0.6768 - val_accuracy: 0.5378
# Epoch 198/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.6684 - accuracy: 0.5635 - val_loss: 0.6770 - val_accuracy: 0.5378
# Epoch 199/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.6682 - accuracy: 0.5702 - val_loss: 0.6764 - val_accuracy: 0.5200
# Epoch 200/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.6684 - accuracy: 0.5746 - val_loss: 0.6765 - val_accuracy: 0.5289

# %%
from matplotlib import pyplot as plt

plt.plot(small_training_results.history['accuracy'],
         label='Accuracy over iterations')
plt.plot(small_training_results.history['loss'], label='Loss over iterations')
plt.legend()

# %%
plt.plot(small_training_results.history['val_accuracy'],
         label='Validation accuracy over iterations')
plt.plot(small_training_results.history['val_loss'],
         label='Validation loss over iterations')
plt.legend()

# %% [markdown]
# # Part 8: Using an RNN

# %%
from tensorflow.keras.layers import LSTM, Embedding

small_rnn_model = keras.Sequential()
small_rnn_model.add(Embedding(len(small_valid_words) + 1, 64, input_length=3))
small_rnn_model.add(LSTM(4, activation='tanh'))
small_rnn_model.add(Dense(1, activation='sigmoid'))
small_rnn_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
small_rnn_model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, 3, 64)             44992
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 4)                 1104
# _________________________________________________________________
# dense_22 (Dense)             (None, 1)                 5
# =================================================================
# Total params: 46,101
# Trainable params: 46,101
# Non-trainable params: 0
# _________________________________________________________________

# %%
small_rnn_results = small_rnn_model.fit(small_X_train, small_y_train, epochs=NUM_EPOCHS, batch_size=SM_BATCH_SIZE, verbose=1, validation_split=0.2, callbacks=[])
# Out:
# Epoch 1/200
# 2021-11-05 17:13:57.872261: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-05 17:13:57.971625: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
#  9/57 [===>..........................] - ETA: 0s - loss: 0.6935 - accuracy: 0.5000
# 2021-11-05 17:13:58.081705: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 57/57 [==============================] - 2s 17ms/step - loss: 0.6935 - accuracy: 0.4878 - val_loss: 0.6933 - val_accuracy: 0.4756
# Epoch 2/200
#  1/57 [..............................] - ETA: 0s - loss: 0.6932 - accuracy: 0.5000
# 2021-11-05 17:13:58.972596: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11
[==============================] - 1s 12ms/step - loss: 0.6903 - accuracy: 0.5011 - val_loss: 0.6811 - val_accuracy: 0.5378

# %%
from matplotlib import pyplot as plt

plt.plot(small_rnn_results.history['accuracy'],
         label='Accuracy over iterations')
plt.plot(small_rnn_results.history['loss'], label='Loss over iterations')
plt.legend()

# %%
plt.plot(small_rnn_results.history['val_accuracy'],
         label='Validation accuracy over iterations')
plt.plot(small_rnn_results.history['val_loss'],
         label='Validation loss over iterations')
plt.legend()

# %%
from tensorflow.keras.layers import LSTM, Embedding

rnn_model = keras.Sequential()
rnn_model.add(Embedding(len(encoded_correct) + 1, 64, input_length=avg_length))
rnn_model.add(LSTM(4, activation='tanh'))
rnn_model.add(Dense(1, activation='sigmoid'))
rnn_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
rnn_model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_5 (Embedding)      (None, 8, 64)             2284288
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 4)                 1104
# _________________________________________________________________
# dense_23 (Dense)             (None, 1)                 5
# =================================================================
# Total params: 2,285,397
# Trainable params: 2,285,397
# Non-trainable params: 0
# _________________________________________________________________

# %%
rnn_results = rnn_model.fit(X_train, y_train, epochs=NUM_EPOCHS, batch_size=VR_BATCH_SIZE, verbose=1, validation_split=0.2, callbacks=[])
# Out:
# Epoch 1/200
# 2021-11-05 17:16:15.482663: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-05 17:16:15.566489: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-05 17:16:15.644535: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 714/714 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5044
# 2021-11-05 17:16:28.512665: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-05 17:16:28.545874: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 714/714 [==============================] - 14s 19ms/step - loss: 0.6932 - accuracy: 0.5044 - val_loss: 0.6931 - val_accuracy: 0.5037
# Epoch 2/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6932 - accuracy: 0.5018 - val_loss: 0.6931 - val_accuracy: 0.5084
# Epoch 3/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6931 - accuracy: 0.5039 - val_loss: 0.6933 - val_accuracy: 0.5021
# Epoch 4/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6924 - accuracy: 0.5051 - val_loss: 0.6888 - val_accuracy: 0.5084
# Epoch 5/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6883 - accuracy: 0.5078 - val_loss: 0.6857 - val_accuracy: 0.5084
# Epoch 6/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6872 - accuracy: 0.5110 - val_loss: 0.6861 - val_accuracy: 0.5037
# Epoch 7/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6871 - accuracy: 0.5061 - val_loss: 0.6852 - val_accuracy: 0.5084
# Epoch 8/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6870 - accuracy: 0.5077 - val_loss: 0.6851 - val_accuracy: 0.5084
# Epoch 9/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6868 - accuracy: 0.5114 - val_loss: 0.6851 - val_accuracy: 0.5084
# Epoch 10/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6868 - accuracy: 0.5094 - val_loss: 0.6849 - val_accuracy: 0.5084
# Epoch 11/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6868 - accuracy: 0.5109 - val_loss: 0.6849 - val_accuracy: 0.5084
# Epoch 12/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6867 - accuracy: 0.5095 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 13/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6867 - accuracy: 0.5101 - val_loss: 0.6849 - val_accuracy: 0.5084
# Epoch 14/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6867 - accuracy: 0.5070 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 15/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6867 - accuracy: 0.5086 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 16/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6866 - accuracy: 0.5103 - val_loss: 0.6852 - val_accuracy: 0.5084
# Epoch 17/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6866 - accuracy: 0.5090 - val_loss: 0.6850 - val_accuracy: 0.5084
# Epoch 18/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6866 - accuracy: 0.5108 - val_loss: 0.6849 - val_accuracy: 0.5084
# Epoch 19/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6866 - accuracy: 0.5061 - val_loss: 0.6847 - val_accuracy: 0.5037
# Epoch 20/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6866 - accuracy: 0.5087 - val_loss: 0.6850 - val_accuracy: 0.5084
# Epoch 21/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6866 - accuracy: 0.5093 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 22/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6866 - accuracy: 0.5095 - val_loss: 0.6847 - val_accuracy: 0.5037
# Epoch 23/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6866 - accuracy: 0.5083 - val_loss: 0.6849 - val_accuracy: 0.5084
# Epoch 24/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5100 - val_loss: 0.6853 - val_accuracy: 0.5084
# Epoch 25/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5097 - val_loss: 0.6851 - val_accuracy: 0.5084
# Epoch 26/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6866 - accuracy: 0.5102 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 27/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6866 - accuracy: 0.5111 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 28/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5086 - val_loss: 0.6853 - val_accuracy: 0.5084
# Epoch 29/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6866 - accuracy: 0.5109 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 30/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5081 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 31/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5113 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 32/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6866 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 33/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 34/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5101 - val_loss: 0.6849 - val_accuracy: 0.5084
# Epoch 35/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6849 - val_accuracy: 0.5084
# Epoch 36/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 37/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5111 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 38/200
# 714/714 [==============================] - 14s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 39/200
# 714/714 [==============================] - 14s 20ms/step - loss: 0.6865 - accuracy: 0.5123 - val_loss: 0.6847 - val_accuracy: 0.5037
# Epoch 40/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5116 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 41/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5103 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 42/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 43/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 44/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 45/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6850 - val_accuracy: 0.5084
# Epoch 46/200
# 714/714 [==============================] - 14s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6849 - val_accuracy: 0.5084
# Epoch 47/200
# 714/714 [==============================] - 14s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 48/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 49/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 50/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 51/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 52/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 53/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 54/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 55/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 56/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5107 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 57/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6849 - val_accuracy: 0.5084
# Epoch 58/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 59/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 60/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 61/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 62/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 63/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 64/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 65/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 66/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 67/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 68/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 69/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 70/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 71/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 72/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 73/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 74/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 75/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 76/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 77/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 78/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 79/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 80/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 81/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 82/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 83/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 84/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 85/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 86/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 87/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 88/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 89/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 90/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 91/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 92/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 93/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 94/200
# 714/714 [==============================] - 14s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 95/200
# 714/714 [==============================] - 14s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 96/200
# 714/714 [==============================] - 14s 20ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 97/200
# 714/714 [==============================] - 14s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 98/200
# 714/714 [==============================] - 14s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 99/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 100/200
# 714/714 [==============================] - 14s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 101/200
# 714/714 [==============================] - 14s 20ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 102/200
# 714/714 [==============================] - 14s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 103/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 104/200
# 714/714 [==============================] - 15s 22ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 105/200
# 714/714 [==============================] - 14s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 106/200
# 714/714 [==============================] - 14s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 107/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 108/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 109/200
# 714/714 [==============================] - 14s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 110/200
# 714/714 [==============================] - 15s 21ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 111/200
# 714/714 [==============================] - 14s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 112/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 113/200
# 714/714 [==============================] - 14s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 114/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 115/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 116/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 117/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 118/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5110 - val_loss: 0.6849 - val_accuracy: 0.5084
# Epoch 119/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 120/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 121/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 122/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 123/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 124/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 125/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 126/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 127/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 128/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 129/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 130/200
# 714/714 [==============================] - 14s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 131/200
# 714/714 [==============================] - 14s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 132/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 133/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 134/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 135/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 136/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 137/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 138/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 139/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 140/200
# 714/714 [==============================] - 14s 20ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 141/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 142/200
# 714/714 [==============================] - 13s 18ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 143/200
# 714/714 [==============================] - 13s 18ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 144/200
# 714/714 [==============================] - 13s 18ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 145/200
# 714/714 [==============================] - 13s 18ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 146/200
# 714/714 [==============================] - 13s 18ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 147/200
# 714/714 [==============================] - 13s 18ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 148/200
# 714/714 [==============================] - 13s 18ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 149/200
# 714/714 [==============================] - 13s 18ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 150/200
# 714/714 [==============================] - 13s 18ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 151/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 152/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 153/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 154/200
# 714/714 [==============================] - 13s 18ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 155/200
# 714/714 [==============================] - 14s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 156/200
# 714/714 [==============================] - 14s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 157/200
# 714/714 [==============================] - 13s 18ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 158/200
# 714/714 [==============================] - 13s 18ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 159/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 160/200
# 714/714 [==============================] - 13s 18ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 161/200
# 714/714 [==============================] - 13s 18ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 162/200
# 714/714 [==============================] - 13s 18ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 163/200
# 714/714 [==============================] - 14s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 164/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 165/200
# 714/714 [==============================] - 13s 18ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 166/200
# 714/714 [==============================] - 13s 18ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 167/200
# 714/714 [==============================] - 13s 18ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 168/200
# 714/714 [==============================] - 14s 20ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 169/200
# 714/714 [==============================] - 14s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 170/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 171/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 172/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 173/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 174/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 175/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 176/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 177/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 178/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 179/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 180/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 181/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 182/200
# 714/714 [==============================] - 14s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 183/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 184/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 185/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 186/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 187/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 188/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 189/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 190/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 191/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 192/200
# 714/714 [==============================] - 13s 18ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 193/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5106 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 194/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 195/200
# 714/714 [==============================] - 14s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 196/200
# 714/714 [==============================] - 14s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 197/200
# 714/714 [==============================] - 13s 19ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084
# Epoch 198/200
# 714/714 [==============================] - 13s 18ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 199/200
# 714/714 [==============================] - 13s 18ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6847 - val_accuracy: 0.5084
# Epoch 200/200
# 714/714 [==============================] - 13s 18ms/step - loss: 0.6865 - accuracy: 0.5120 - val_loss: 0.6848 - val_accuracy: 0.5084

# %%
from matplotlib import pyplot as plt

plt.plot(rnn_results.history['accuracy'],
         label='Accuracy over iterations')
plt.plot(rnn_results.history['loss'], label='Loss over iterations')
plt.legend()

# %%
plt.plot(rnn_results.history['val_accuracy'],
         label='Validation accuracy over iterations')
plt.plot(rnn_results.history['val_loss'],
         label='Validation loss over iterations')
plt.legend()

# %% [markdown]
# # Part 8: Comparing Network Scores

# %%
NETWORKS = [init_model, small_model, small_rnn_model, rnn_model]
RESULTS = {
    "Original (Avg Length)": training_results,
    "Small (3 Chars)": small_training_results,
    "Small RNN (3 Chars)": small_rnn_results,
    "RNN (Avg. Length": rnn_results
}

# %%
for RESULT_NAME, RESULT_DATA in RESULTS.items():
    plt.plot(RESULT_DATA.history["loss"], label=RESULT_NAME)
plt.title('Loss of Networks')
plt.legend()

# %%
for RESULT_NAME, RESULT_DATA in RESULTS.items():
    plt.plot(RESULT_DATA.history["accuracy"], label=RESULT_NAME)
plt.title('Accuracy of Networks')
plt.legend()

# %%
for RESULT_NAME, RESULT_DATA in RESULTS.items():
    plt.plot(RESULT_DATA.history["val_loss"], label=RESULT_NAME)
plt.title('Validation Loss of Networks')
plt.legend()

# %%
for RESULT_NAME, RESULT_DATA in RESULTS.items():
    plt.plot(RESULT_DATA.history["val_accuracy"], label=RESULT_NAME)
plt.title('Validation Accuracy of Networks')
plt.legend()
